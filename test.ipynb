# %%
from src.utils.dataset_loader import get_Market1501

# %%
dataset = get_Market1501("datasets/Market-1501", 224)

# %%
len(dataset)
# Out:
# 2

# %%
dataset["train"].classes
# Out:
# ['0002',
#  '0007',
#  '0010',
#  '0011',
#  '0012',
#  '0020',
#  '0022',
#  '0023',
#  '0027',
#  '0028',
#  '0030',
#  '0032',
#  '0035',
#  '0037',
#  '0042',
#  '0043',
#  '0046',
#  '0047',
#  '0048',
#  '0052',
#  '0053',
#  '0056',
#  '0057',
#  '0059',
#  '0064',
#  '0065',
#  '0067',
#  '0068',
#  '0069',
#  '0070',
#  '0076',
#  '0077',
#  '0079',
#  '0081',
#  '0082',
#  '0084',
#  '0086',
#  '0088',
#  '0090',
#  '0093',
#  '0095',
#  '0097',
#  '0098',
#  '0099',
#  '0100',
#  '0104',
#  '0105',
#  '0106',
#  '0107',
#  '0108',
#  '0110',
#  '0111',
#  '0114',
#  '0115',
#  '0116',
#  '0117',
#  '0118',
#  '0121',
#  '0122',
#  '0123',
#  '0125',
#  '0127',
#  '0129',
#  '0132',
#  '0134',
#  '0135',
#  '0136',
#  '0139',
#  '0140',
#  '0141',
#  '0142',
#  '0143',
#  '0148',
#  '0149',
#  '0150',
#  '0151',
#  '0158',
#  '0159',
#  '0160',
#  '0162',
#  '0164',
#  '0166',
#  '0167',
#  '0169',
#  '0172',
#  '0173',
#  '0175',
#  '0176',
#  '0177',
#  '0178',
# ...

# %%
len(dataset["val"][100][1])
# Out:
# 100

# %%
dataset["train"][100][0].shape
# Out:
# torch.Size([3, 224, 224])
